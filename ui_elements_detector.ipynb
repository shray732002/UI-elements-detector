# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.3/664.3 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/data'
# !ls '/content/drive/MyDrive/data/train'
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
# images	labels	labels.cache

# %%
import numpy as np
import cv2

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/content/drive/MyDrive/data/data.yaml", epochs=25, imgsz=640)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 190MB/s]
# Ultralytics YOLOv8.0.234 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.234 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25847287 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/data/valid/labels.cache... 3 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3/3 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
#                    all          3        212      0.618      0.484      0.475      0.326
#                 button          3         20      0.449      0.408       0.38      0.286
#               checkbox          3          8          1          0      0.197      0.155
#               dropdown          3         31      0.217      0.187      0.223      0.112
#                   form          3          1          1          0      0.332      0.133
#                  image          3         10       0.75          1      0.922      0.814
# ...

# %%
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train2/F1_curve.png')
y = Image(filename='runs/detect/train2/PR_curve.png')
z = Image(filename='runs/detect/train2/confusion_matrix.png')
display(x, y,z)

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !ls runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
model = YOLO("runs/detect/train/weights/best.pt")  # load a custom model
